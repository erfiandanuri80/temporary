# %%
import pandas as pd
from scipy import stats
d=pd.read_csv('Book1.csv')
#d=pd.read_excel("Book1.xlsx")
d
# Out:
#     beratbadan  tinggibadan  umur  banyaksaudara
# 0           67          157    22              5
# 1           76          165    21              2
# 2           84          156    22              2
# 3           51          167    22              2
# 4           93          192    21              5
# 5           90          171    30              4
# 6           93          187    16              2
# 7           77          163    26              4
# 8           71          153    28              3
# 9           54          167    18              5
# 10          78          196    18              5
# 11          85          159    22              4
# 12          72          192    25              3
# 13          88          164    20              3
# 14          87          172    25              3
# 15          86          198    28              3
# 16          91          177    29              1
# 17          66          174    30              4
# ...

# %%
df=pd.read_csv('Book1.csv',usecols=["beratbadan","tinggibadan","umur","banyaksaudara"])
df.describe()
# Out:
#        beratbadan  tinggibadan        umur  banyaksaudara
# count  100.000000   100.000000  100.000000     100.000000
# mean    73.190000   175.070000   22.390000       3.040000
# std     13.813838    14.286573    4.483178       1.434918
# min     50.000000   150.000000   15.000000       1.000000
# 25%     61.750000   163.750000   18.750000       2.000000
# 50%     71.000000   174.000000   22.000000       3.000000
# 75%     86.000000   186.250000   26.250000       4.000000
# max     99.000000   200.000000   30.000000       5.000000

# %%
from scipy import stats
mode= stats.mode(df)
print(mode)
# Out:
# ModeResult(mode=array([[ 72, 183,  22,   5]], dtype=int64), count=array([[ 5,  5,  9, 22]]))

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.distplot(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-cc90fd0b0a3e> in <module>
#       1 import seaborn as sns
#       2 sns.set(color_codes=True)
# ----> 3 sns.distplot(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     223         hist_color = hist_kws.pop("color", color)
#     224         ax.hist(a, bins, orientation=orientation,
# --> 225                 color=hist_color, **hist_kws)
#     226         if hist_color != color:
#     227             hist_kws["color"] = hist_color
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
"""
x=0
temp=[]
for i in range(4):
    df=pd.read_csv('Book1.csv',usecols=[x])
    a=df.describe()
    temp.append(a)
    x=x+1
print(temp)
"""
# Out:
# "\nx=0\ntemp=[]\nfor i in range(4):\n    df=pd.read_csv('Book1.csv',usecols=[x])\n    a=df.describe()\n    temp.append(a)\n    x=x+1\nprint(temp)\n"
